# %% [markdown]
# <img src="mioti.png" style="height: 100px">
# <center style="color:#888">Módulo Data Science in IoT<br/>Asignatura Data preprocessing</center>
#
# # Challenge S6: Reglas de asociación para análisis de cesta de la compra

# %% [markdown]
# ## Objetivos
#
# El objetivo de este challenge es enfrentarse a un problema de generación de reglas de asociación real: a partir de datos de transacciones de compra de un supermercado, realizar un estudio de la cesta de la compra (*market basket analysis*) mediante la generación de reglas de asociación.

# %%
# Descomentar esto para instalar paquete mlxtend
#import sys
#!{sys.executable} -m pip install mlxtend

from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

import pandas as pd

# %% [markdown]
# ## Carga de datos
#
# Para comenzar, cargamos el fichero de tickets de venta:

# %%
df = pd.read_excel('data/Online Retail.xlsx')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %% [markdown]
# Y lo convertimos al formato esperado por la librería de reglas de asociación

# %%
# Preprocesamiento y filtrado de columnas no útiles
df['Description'] = df['Description'].str.strip()
df.dropna(axis=0, subset=['InvoiceNo'], inplace=True)
df['InvoiceNo'] = df['InvoiceNo'].astype('str')
df = df[~df['InvoiceNo'].str.contains('C')]

# Filtramos por país, agrupamos por ticket y transponemos
basket = (df[df['Country'] =="Germany"]
          .groupby(['InvoiceNo', 'Description'])['Quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('InvoiceNo'))

# %%
basket.head()
# Out:
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536527                          0.0                         0.0
# 536840                          0.0                         0.0
# 536861                          0.0                         0.0
# 536967                          0.0                         0.0
# 536983                          0.0                         0.0
#
# Description  12 IVORY ROSE PEG PLACE SETTINGS  \
# InvoiceNo
# 536527                                    0.0
# 536840                                    0.0
# 536861                                    0.0
# 536967                                    0.0
# 536983                                    0.0
#
# Description  12 MESSAGE CARDS WITH ENVELOPES  12 PENCIL SMALL TUBE WOODLAND  \
# InvoiceNo
# 536527                                   0.0                            0.0
# 536840                                   0.0                            0.0
# 536861                                   0.0                            0.0
# 536967                                   0.0                            0.0
# 536983                                   0.0                            0.0
#
# Description  12 PENCILS SMALL TUBE RED RETROSPOT  12 PENCILS SMALL TUBE SKULL  \
# InvoiceNo
# 536527                                       0.0                          0.0
# 536840                                       0.0                          0.0
# 536861                                       0.0                          0.0
# 536967                                       0.0                          0.0
# 536983                                       0.0                          0.0
#
# Description  12 PENCILS TALL TUBE POSY  12 PENCILS TALL TUBE RED RETROSPOT  \
# InvoiceNo
# 536527                             0.0                                 0.0
# 536840                             0.0                                 0.0
# 536861                             0.0                                 0.0
# 536967                             0.0                                 0.0
# 536983                             0.0                                 0.0
#
# Description  12 PENCILS TALL TUBE SKULLS                ...                 \
# InvoiceNo                                               ...
# 536527                               0.0                ...
# 536840                               0.0                ...
# 536861                               0.0                ...
# 536967                               0.0                ...
# 536983                               0.0                ...
#
# Description  YULETIDE IMAGES GIFT WRAP SET  ZINC  HEART T-LIGHT HOLDER  \
# InvoiceNo
# 536527                                 0.0                         0.0
# 536840                                 0.0                         0.0
# 536861                                 0.0                         0.0
# 536967                                 0.0                         0.0
# 536983                                 0.0                         0.0
#
# Description  ZINC  STAR T-LIGHT HOLDER  ZINC BOX SIGN HOME  \
# InvoiceNo
# 536527                             0.0                 0.0
# 536840                             0.0                 0.0
# 536861                             0.0                 0.0
# 536967                             0.0                 0.0
# 536983                             0.0                 0.0
#
# Description  ZINC FOLKART SLEIGH BELLS  ZINC HEART LATTICE T-LIGHT HOLDER  \
# InvoiceNo
# 536527                             0.0                                0.0
# 536840                             0.0                                0.0
# 536861                             0.0                                0.0
# 536967                             0.0                                0.0
# 536983                             0.0                                0.0
#
# Description  ZINC METAL HEART DECORATION  ZINC T-LIGHT HOLDER STAR LARGE  \
# InvoiceNo
# 536527                               0.0                             0.0
# 536840                               0.0                             0.0
# 536861                               0.0                             0.0
# 536967                               0.0                             0.0
# 536983                               0.0                             0.0
#
# Description  ZINC T-LIGHT HOLDER STARS SMALL  ZINC WILLIE WINKIE  CANDLE STICK
# InvoiceNo
# 536527                                   0.0                               0.0
# 536840                                   0.0                               0.0
# 536861                                   0.0                               0.0
# 536967                                   0.0                               0.0
# 536983                                   0.0                               0.0
#
# [5 rows x 1695 columns]

# %%
# Convertimos los binarios a enteros
def encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1

# %%
basket_sets = basket.applymap(encode_units)
basket_sets.drop('POSTAGE', inplace=True, axis=1)

# %%
basket_sets.head()
# Out:
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536527                            0                           0
# 536840                            0                           0
# 536861                            0                           0
# 536967                            0                           0
# 536983                            0                           0
#
# Description  12 IVORY ROSE PEG PLACE SETTINGS  \
# InvoiceNo
# 536527                                      0
# 536840                                      0
# 536861                                      0
# 536967                                      0
# 536983                                      0
#
# Description  12 MESSAGE CARDS WITH ENVELOPES  12 PENCIL SMALL TUBE WOODLAND  \
# InvoiceNo
# 536527                                     0                              0
# 536840                                     0                              0
# 536861                                     0                              0
# 536967                                     0                              0
# 536983                                     0                              0
#
# Description  12 PENCILS SMALL TUBE RED RETROSPOT  12 PENCILS SMALL TUBE SKULL  \
# InvoiceNo
# 536527                                         0                            0
# 536840                                         0                            0
# 536861                                         0                            0
# 536967                                         0                            0
# 536983                                         0                            0
#
# Description  12 PENCILS TALL TUBE POSY  12 PENCILS TALL TUBE RED RETROSPOT  \
# InvoiceNo
# 536527                               0                                   0
# 536840                               0                                   0
# 536861                               0                                   0
# 536967                               0                                   0
# 536983                               0                                   0
#
# Description  12 PENCILS TALL TUBE SKULLS                ...                 \
# InvoiceNo                                               ...
# 536527                                 0                ...
# 536840                                 0                ...
# 536861                                 0                ...
# 536967                                 0                ...
# 536983                                 0                ...
#
# Description  YULETIDE IMAGES GIFT WRAP SET  ZINC  HEART T-LIGHT HOLDER  \
# InvoiceNo
# 536527                                   0                           0
# 536840                                   0                           0
# 536861                                   0                           0
# 536967                                   0                           0
# 536983                                   0                           0
#
# Description  ZINC  STAR T-LIGHT HOLDER  ZINC BOX SIGN HOME  \
# InvoiceNo
# 536527                               0                   0
# 536840                               0                   0
# 536861                               0                   0
# 536967                               0                   0
# 536983                               0                   0
#
# Description  ZINC FOLKART SLEIGH BELLS  ZINC HEART LATTICE T-LIGHT HOLDER  \
# InvoiceNo
# 536527                               0                                  0
# 536840                               0                                  0
# 536861                               0                                  0
# 536967                               0                                  0
# 536983                               0                                  0
#
# Description  ZINC METAL HEART DECORATION  ZINC T-LIGHT HOLDER STAR LARGE  \
# InvoiceNo
# 536527                                 0                               0
# 536840                                 0                               0
# 536861                                 0                               0
# 536967                                 0                               0
# 536983                                 0                               0
#
# Description  ZINC T-LIGHT HOLDER STARS SMALL  ZINC WILLIE WINKIE  CANDLE STICK
# InvoiceNo
# 536527                                     0                                 0
# 536840                                     0                                 0
# 536861                                     0                                 0
# 536967                                     0                                 0
# 536983                                     0                                 0
#
# [5 rows x 1694 columns]

# %% [markdown]
# * ¿Cuál es el tamaño de nuestro conjunto de items $I$ ?

# %% [markdown]
# 1694

# %% [markdown]
# * ¿ Cuál es el tamaño de nuestro conjunto de transacciones $D$ ?

# %% [markdown]
# 5

# %% [markdown]
# ## Reglas de asociación con mlxtend
#
# Ahora vamos a utilizar la librería [`mlxtend`](http://rasbt.github.io/mlxtend/user_guide/frequent_patterns/association_rules/) para generar las reglas de asociación más interesantes en nuestro conjunto de datos.
#
# * Comenzamos calculando el soporte de los itemsets frecuentes de nuestro conjunto, aplicando un umbral mínimo de 0.07:

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
frequent_itemsets = apriori(basket_sets, min_support=0.07, use_colnames=True)
frequent_itemsets
# Out:
#      support                                           itemsets
# 0   0.102845                           (6 RIBBONS RUSTIC CHARM)
# 1   0.070022                        (ALARM CLOCK BAKELIKE PINK)
# 2   0.072210                                (GUMBALL COAT RACK)
# 3   0.091904                           (JAM MAKING SET PRINTED)
# 4   0.078775                          (JUMBO BAG RED RETROSPOT)
# 5   0.100656                       (JUMBO BAG WOODLAND ANIMALS)
# 6   0.078775                               (LUNCH BAG WOODLAND)
# 7   0.085339                  (PACK OF 72 RETROSPOT CAKE CASES)
# 8   0.115974                    (PLASTERS IN TIN CIRCUS PARADE)
# 9   0.107221                         (PLASTERS IN TIN SPACEBOY)
# 10  0.070022                        (PLASTERS IN TIN STRONGMAN)
# 11  0.137856                 (PLASTERS IN TIN WOODLAND ANIMALS)
# 12  0.070022                      (RED RETROSPOT CHARLOTTE BAG)
# 13  0.070022                                (RED RETROSPOT CUP)
# 14  0.096280                    (RED TOADSTOOL LED NIGHT LIGHT)
# 15  0.137856                         (REGENCY CAKESTAND 3 TIER)
# 16  0.157549                (ROUND SNACK BOXES SET OF 4 FRUITS)
# 17  0.245077               (ROUND SNACK BOXES SET OF4 WOODLAND)
# 18  0.070022                       (SET OF 3 REGENCY CAKE TINS)
# 19  0.102845                               (SPACEBOY LUNCH BOX)
# 20  0.078775                (STRAWBERRY LUNCH BOX WITH CUTLERY)
# 21  0.126915                           (WOODLAND CHARLOTTE BAG)
# 22  0.074398  (ROUND SNACK BOXES SET OF4 WOODLAND, PLASTERS ...
# 23  0.131291  (ROUND SNACK BOXES SET OF4 WOODLAND, ROUND SNA...
# 24  0.070022  (ROUND SNACK BOXES SET OF4 WOODLAND, SPACEBOY ...

# %% [markdown]
# * Prueba a ejecutar el mismo algoritmo apriori con umbral mínimo de soporte de 0.05 y 0.09. ¿Qué observas? ¿A qué crees que se debe?

# %%
frequent_itemsets = apriori(basket_sets, min_support=0.07, use_colnames=True)
frequent_itemsets
# Out:
#      support                                           itemsets
# 0   0.102845                           (6 RIBBONS RUSTIC CHARM)
# 1   0.070022                        (ALARM CLOCK BAKELIKE PINK)
# 2   0.072210                                (GUMBALL COAT RACK)
# 3   0.091904                           (JAM MAKING SET PRINTED)
# 4   0.078775                          (JUMBO BAG RED RETROSPOT)
# 5   0.100656                       (JUMBO BAG WOODLAND ANIMALS)
# 6   0.078775                               (LUNCH BAG WOODLAND)
# 7   0.085339                  (PACK OF 72 RETROSPOT CAKE CASES)
# 8   0.115974                    (PLASTERS IN TIN CIRCUS PARADE)
# 9   0.107221                         (PLASTERS IN TIN SPACEBOY)
# 10  0.070022                        (PLASTERS IN TIN STRONGMAN)
# 11  0.137856                 (PLASTERS IN TIN WOODLAND ANIMALS)
# 12  0.070022                      (RED RETROSPOT CHARLOTTE BAG)
# 13  0.070022                                (RED RETROSPOT CUP)
# 14  0.096280                    (RED TOADSTOOL LED NIGHT LIGHT)
# 15  0.137856                         (REGENCY CAKESTAND 3 TIER)
# 16  0.157549                (ROUND SNACK BOXES SET OF 4 FRUITS)
# 17  0.245077               (ROUND SNACK BOXES SET OF4 WOODLAND)
# 18  0.070022                       (SET OF 3 REGENCY CAKE TINS)
# 19  0.102845                               (SPACEBOY LUNCH BOX)
# 20  0.078775                (STRAWBERRY LUNCH BOX WITH CUTLERY)
# 21  0.126915                           (WOODLAND CHARLOTTE BAG)
# 22  0.074398  (ROUND SNACK BOXES SET OF4 WOODLAND, PLASTERS ...
# 23  0.131291  (ROUND SNACK BOXES SET OF4 WOODLAND, ROUND SNA...
# 24  0.070022  (ROUND SNACK BOXES SET OF4 WOODLAND, SPACEBOY ...

# %%
frequent_itemsets = apriori(basket_sets, min_support=0.05, use_colnames=True)
frequent_itemsets
# Out:
#      support                                           itemsets
# 0   0.102845                           (6 RIBBONS RUSTIC CHARM)
# 1   0.070022                        (ALARM CLOCK BAKELIKE PINK)
# 2   0.065646                      (CHARLOTTE BAG APPLES DESIGN)
# 3   0.050328                     (CHILDRENS CUTLERY DOLLY GIRL)
# 4   0.061269                         (COFFEE MUG APPLES DESIGN)
# 5   0.063457                       (FAWN BLUE HOT WATER BOTTLE)
# 6   0.072210                                (GUMBALL COAT RACK)
# 7   0.056893                             (IVORY KITCHEN SCALES)
# 8   0.063457                            (JAM JAR WITH PINK LID)
# 9   0.091904                           (JAM MAKING SET PRINTED)
# 10  0.061269                                 (JUMBO BAG APPLES)
# 11  0.078775                          (JUMBO BAG RED RETROSPOT)
# 12  0.100656                       (JUMBO BAG WOODLAND ANIMALS)
# 13  0.061269                           (LUNCH BAG APPLE DESIGN)
# 14  0.078775                               (LUNCH BAG WOODLAND)
# 15  0.063457                 (LUNCH BOX WITH CUTLERY RETROSPOT)
# 16  0.054705                        (MEMO BOARD COTTAGE DESIGN)
# 17  0.052516                              (MINT KITCHEN SCALES)
# 18  0.061269                 (PACK OF 20 NAPKINS PANTRY DESIGN)
# 19  0.059081                    (PACK OF 20 NAPKINS RED APPLES)
# 20  0.085339                  (PACK OF 72 RETROSPOT CAKE CASES)
# 21  0.115974                    (PLASTERS IN TIN CIRCUS PARADE)
# 22  0.107221                         (PLASTERS IN TIN SPACEBOY)
# 23  0.070022                        (PLASTERS IN TIN STRONGMAN)
# 24  0.137856                 (PLASTERS IN TIN WOODLAND ANIMALS)
# 25  0.050328                               (RABBIT NIGHT LIGHT)
# 26  0.054705                               (RED KITCHEN SCALES)
# 27  0.070022                      (RED RETROSPOT CHARLOTTE BAG)
# 28  0.070022                                (RED RETROSPOT CUP)
# 29  0.065646                         (RED RETROSPOT MINI CASES)
# 30  0.096280                    (RED TOADSTOOL LED NIGHT LIGHT)
# 31  0.137856                         (REGENCY CAKESTAND 3 TIER)
# 32  0.061269                (RETROSPOT PARTY BAG + STICKER SET)
# 33  0.056893                  (RETROSPOT TEA SET CERAMIC 11 PC)
# 34  0.157549                (ROUND SNACK BOXES SET OF 4 FRUITS)
# 35  0.245077               (ROUND SNACK BOXES SET OF4 WOODLAND)
# 36  0.050328                   (SET 2 PANTRY DESIGN TEA TOWELS)
# 37  0.059081                 (SET OF 3 CAKE TINS PANTRY DESIGN)
# 38  0.070022                       (SET OF 3 REGENCY CAKE TINS)
# 39  0.056893               (SET OF 60 PANTRY DESIGN CAKE CASES)
# 40  0.056893               (SET/20 RED RETROSPOT PAPER NAPKINS)
# 41  0.052516                      (SET/6 RED SPOTTY PAPER CUPS)
# 42  0.056893                    (SET/6 RED SPOTTY PAPER PLATES)
# 43  0.056893                     (SKULL LUNCH BOX WITH CUTLERY)
# 44  0.102845                               (SPACEBOY LUNCH BOX)
# 45  0.052516                   (STRAWBERRY CERAMIC TRINKET BOX)
# 46  0.078775                (STRAWBERRY LUNCH BOX WITH CUTLERY)
# 47  0.052516               (WHITE SPOT RED CERAMIC DRAWER KNOB)
# 48  0.126915                           (WOODLAND CHARLOTTE BAG)
# 49  0.067834                 (WOODLAND PARTY BAG + STICKER SET)
# 50  0.067834  (PLASTERS IN TIN CIRCUS PARADE, PLASTERS IN TI...
# 51  0.050328  (PLASTERS IN TIN CIRCUS PARADE, ROUND SNACK BO...
# 52  0.056893  (ROUND SNACK BOXES SET OF4 WOODLAND, PLASTERS ...
# 53  0.061269  (PLASTERS IN TIN WOODLAND ANIMALS, PLASTERS IN...
# 54  0.074398  (ROUND SNACK BOXES SET OF4 WOODLAND, PLASTERS ...
# 55  0.059081  (RED RETROSPOT CHARLOTTE BAG, WOODLAND CHARLOT...
# 56  0.131291  (ROUND SNACK BOXES SET OF4 WOODLAND, ROUND SNA...
# 57  0.070022  (ROUND SNACK BOXES SET OF4 WOODLAND, SPACEBOY ...
# 58  0.063457  (ROUND SNACK BOXES SET OF4 WOODLAND, WOODLAND ...

# %%
frequent_itemsets = apriori(basket_sets, min_support=0.09, use_colnames=True)
frequent_itemsets
# Out:
#      support                                           itemsets
# 0   0.102845                           (6 RIBBONS RUSTIC CHARM)
# 1   0.091904                           (JAM MAKING SET PRINTED)
# 2   0.100656                       (JUMBO BAG WOODLAND ANIMALS)
# 3   0.115974                    (PLASTERS IN TIN CIRCUS PARADE)
# 4   0.107221                         (PLASTERS IN TIN SPACEBOY)
# 5   0.137856                 (PLASTERS IN TIN WOODLAND ANIMALS)
# 6   0.096280                    (RED TOADSTOOL LED NIGHT LIGHT)
# 7   0.137856                         (REGENCY CAKESTAND 3 TIER)
# 8   0.157549                (ROUND SNACK BOXES SET OF 4 FRUITS)
# 9   0.245077               (ROUND SNACK BOXES SET OF4 WOODLAND)
# 10  0.102845                               (SPACEBOY LUNCH BOX)
# 11  0.126915                           (WOODLAND CHARLOTTE BAG)
# 12  0.131291  (ROUND SNACK BOXES SET OF4 WOODLAND, ROUND SNA...

# %% [markdown]
# De ahora en adelante utilizaremos el primer soporte calculado con un umbral de valor 0.07.
#
# * ¿Cuál es el item con mayor valor de soporte?

# %% [markdown]
# (ROUND SNACK BOXES SET OF4 WOODLAND)

# %%
frequent_itemsets = apriori(basket_sets, min_support=0.07, use_colnames=True)
frequent_itemsets
# Out:
#      support                                           itemsets
# 0   0.102845                           (6 RIBBONS RUSTIC CHARM)
# 1   0.070022                        (ALARM CLOCK BAKELIKE PINK)
# 2   0.072210                                (GUMBALL COAT RACK)
# 3   0.091904                           (JAM MAKING SET PRINTED)
# 4   0.078775                          (JUMBO BAG RED RETROSPOT)
# 5   0.100656                       (JUMBO BAG WOODLAND ANIMALS)
# 6   0.078775                               (LUNCH BAG WOODLAND)
# 7   0.085339                  (PACK OF 72 RETROSPOT CAKE CASES)
# 8   0.115974                    (PLASTERS IN TIN CIRCUS PARADE)
# 9   0.107221                         (PLASTERS IN TIN SPACEBOY)
# 10  0.070022                        (PLASTERS IN TIN STRONGMAN)
# 11  0.137856                 (PLASTERS IN TIN WOODLAND ANIMALS)
# 12  0.070022                      (RED RETROSPOT CHARLOTTE BAG)
# 13  0.070022                                (RED RETROSPOT CUP)
# 14  0.096280                    (RED TOADSTOOL LED NIGHT LIGHT)
# 15  0.137856                         (REGENCY CAKESTAND 3 TIER)
# 16  0.157549                (ROUND SNACK BOXES SET OF 4 FRUITS)
# 17  0.245077               (ROUND SNACK BOXES SET OF4 WOODLAND)
# 18  0.070022                       (SET OF 3 REGENCY CAKE TINS)
# 19  0.102845                               (SPACEBOY LUNCH BOX)
# 20  0.078775                (STRAWBERRY LUNCH BOX WITH CUTLERY)
# 21  0.126915                           (WOODLAND CHARLOTTE BAG)
# 22  0.074398  (ROUND SNACK BOXES SET OF4 WOODLAND, PLASTERS ...
# 23  0.131291  (ROUND SNACK BOXES SET OF4 WOODLAND, ROUND SNA...
# 24  0.070022  (ROUND SNACK BOXES SET OF4 WOODLAND, SPACEBOY ...

# %%
frequent_itemsets.sort_values(by='support')
# Out:
#      support                                           itemsets
# 12  0.070022                      (RED RETROSPOT CHARLOTTE BAG)
# 18  0.070022                       (SET OF 3 REGENCY CAKE TINS)
# 13  0.070022                                (RED RETROSPOT CUP)
# 10  0.070022                        (PLASTERS IN TIN STRONGMAN)
# 24  0.070022  (ROUND SNACK BOXES SET OF4 WOODLAND, SPACEBOY ...
# 1   0.070022                        (ALARM CLOCK BAKELIKE PINK)
# 2   0.072210                                (GUMBALL COAT RACK)
# 22  0.074398  (ROUND SNACK BOXES SET OF4 WOODLAND, PLASTERS ...
# 6   0.078775                               (LUNCH BAG WOODLAND)
# 20  0.078775                (STRAWBERRY LUNCH BOX WITH CUTLERY)
# 4   0.078775                          (JUMBO BAG RED RETROSPOT)
# 7   0.085339                  (PACK OF 72 RETROSPOT CAKE CASES)
# 3   0.091904                           (JAM MAKING SET PRINTED)
# 14  0.096280                    (RED TOADSTOOL LED NIGHT LIGHT)
# 5   0.100656                       (JUMBO BAG WOODLAND ANIMALS)
# 19  0.102845                               (SPACEBOY LUNCH BOX)
# 0   0.102845                           (6 RIBBONS RUSTIC CHARM)
# 9   0.107221                         (PLASTERS IN TIN SPACEBOY)
# 8   0.115974                    (PLASTERS IN TIN CIRCUS PARADE)
# 21  0.126915                           (WOODLAND CHARLOTTE BAG)
# 23  0.131291  (ROUND SNACK BOXES SET OF4 WOODLAND, ROUND SNA...
# 15  0.137856                         (REGENCY CAKESTAND 3 TIER)
# 11  0.137856                 (PLASTERS IN TIN WOODLAND ANIMALS)
# 16  0.157549                (ROUND SNACK BOXES SET OF 4 FRUITS)
# 17  0.245077               (ROUND SNACK BOXES SET OF4 WOODLAND)

# %% [markdown]
# * Ahora vamos a calcular las reglas de asociación utilizando el soporte calculado previamente. Prueba utilizando la métrica confidence con un umbral mínimo de 1.

# %%
as_conf = association_rules(frequent_itemsets, metric="confidence", min_threshold=1)
as_conf
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction]
# Index: []

# %% [markdown]
# * Ahora prueba utilizando la métrica lift con un umbral mínimo de 1.

# %%
as_lift = association_rules(frequent_itemsets, metric="lift", min_threshold=1)
as_lift
# Out:
#                             antecedents                           consequents  \
# 0  (ROUND SNACK BOXES SET OF4 WOODLAND)    (PLASTERS IN TIN WOODLAND ANIMALS)
# 1    (PLASTERS IN TIN WOODLAND ANIMALS)  (ROUND SNACK BOXES SET OF4 WOODLAND)
# 2  (ROUND SNACK BOXES SET OF4 WOODLAND)   (ROUND SNACK BOXES SET OF 4 FRUITS)
# 3   (ROUND SNACK BOXES SET OF 4 FRUITS)  (ROUND SNACK BOXES SET OF4 WOODLAND)
# 4  (ROUND SNACK BOXES SET OF4 WOODLAND)                  (SPACEBOY LUNCH BOX)
# 5                  (SPACEBOY LUNCH BOX)  (ROUND SNACK BOXES SET OF4 WOODLAND)
#
#    antecedent support  consequent support   support  confidence      lift  \
# 0            0.245077            0.137856  0.074398    0.303571  2.202098
# 1            0.137856            0.245077  0.074398    0.539683  2.202098
# 2            0.245077            0.157549  0.131291    0.535714  3.400298
# 3            0.157549            0.245077  0.131291    0.833333  3.400298
# 4            0.245077            0.102845  0.070022    0.285714  2.778116
# 5            0.102845            0.245077  0.070022    0.680851  2.778116
#
#    leverage  conviction
# 0  0.040613    1.237951
# 1  0.040613    1.640006
# 2  0.092679    1.814509
# 3  0.092679    4.529540
# 4  0.044817    1.256018
# 5  0.044817    2.365427

# %% [markdown]
# * Sobre estas últimas reglas calculadas, filtra aquellas que tengan un lift mayor que 1.5 y un confidence mayor que 0.7

# %%
mask = (as_lift['lift'] > 1.5) & (as_lift['confidence'] > 0.7)
as_lift[mask]
# Out:
#                            antecedents                           consequents  \
# 3  (ROUND SNACK BOXES SET OF 4 FRUITS)  (ROUND SNACK BOXES SET OF4 WOODLAND)
#
#    antecedent support  consequent support   support  confidence      lift  \
# 3            0.157549            0.245077  0.131291    0.833333  3.400298
#
#    leverage  conviction
# 3  0.092679     4.52954

# %% [markdown]
# * ¿Cómo intepretarías el significado en concreto de estas reglas de asociación generadas?

# %% [markdown]
#  Para estas reglas, se puede concluir que existen pocos items que tengan dependencia entre sí; además de que las que existen asociación no hay un 100% de certeza de esa asociación.
#
#  Esto también implica que los productos pueden tener en efecto negativo el uno sobre el otro.

# %% [markdown]
# ## Reglas de asociación a mano
#
# Tomemos como ejemplo la regla de asociación generada en el paso previo. Vamos a realizar los cálculos previamente obtenidos por `mlxtend`, ahora nosotros a mano.
#
# * Comenzamos por el soporte. Calcula el soporte del antecedente, del consecuente y de ambos, de la última regla de asociación (sin utilizar mlxtend).

# %%
sum(basket_sets['ROUND SNACK BOXES SET OF 4 FRUITS'])/len(basket_sets)
# Out:
# 0.1575492341356674

# %%
sum(basket_sets['ROUND SNACK BOXES SET OF4 WOODLAND'])/len(basket_sets)
# Out:
# 0.24507658643326038

# %% [markdown]
# * Una vez calculado los soportes, calcula la confianza (confidence) de la regla.

# %%
0.131291/(sum(basket_sets['ROUND SNACK BOXES SET OF 4 FRUITS'])/len(basket_sets))
# Out:
# 0.8333331527777776

# %% [markdown]
# * Ahora calcula el lift.

# %%
0.131291/((sum(basket_sets['ROUND SNACK BOXES SET OF 4 FRUITS'])/len(basket_sets))*sum(basket_sets['ROUND SNACK BOXES SET OF4 WOODLAND'])/len(basket_sets))
# Out:
# 3.400296882316468

# %% [markdown]
# Comprueba que obtienes los mismos resultados que con `mlxtend`.
